# %% [markdown]
# # Exercise 12: Looping Over Data Sets

# %% [markdown]
# ## Aim: Use `glob` to find sets of files, and write loops to perform operations on files.

# %% [markdown]
# ### Issues covered:
# - Using a `for` loop to loop over a given list of files
# - Using `glob` to match patterns of files
# - Looping over sets of files using `glob`
# - Using `glob` and `for` to process data from mutliple files

# %% [markdown]
# ## 1. Looping over files from a simple list

# %% [markdown]
# Use a `for` loop to loop over the files in the data folder (americas_gdp.csv, europe_gdp.csv and oceania_gdp.csv) and print out the maxima of the datasets.

# %%
import pandas as pd
import glob

# %%
datafolder = ('/home/users/train023/my-ics-work/python-intro/data/')
for filename in datafolder:
    print(filename)
# Out:
# /
# h
# o
# m
# e
# /
# u
# s
# e
# r
# s
# /
# t
# r
# a
# i
# n
# 0
# 2
# 3
# /
# m
# y
# -
# i
# c
# s
# -
# w
# o
# r
# k
# /
# p
# y
# t
# h
# o
# n
# -
# i
# n
# t
# r
# o
# /
# d
# a
# t
# a
# /

# %% [markdown]
# ## 2. Using `glob` to loop through files

# %% [markdown]
# What do you think `glob.glob('*.ipynb')` will return? Try it and see.

# %%
for filename in glob.glob('/home/users/train023/my-ics-work/python-intro/exercises/*.ipynb'):
    print(filename)
# Out:
# /home/users/train023/my-ics-work/python-intro/exercises/ex02_variables_assignment.ipynb
# /home/users/train023/my-ics-work/python-intro/exercises/ex03_data_types.ipynb
# /home/users/train023/my-ics-work/python-intro/exercises/ex09_lists.ipynb
# /home/users/train023/my-ics-work/python-intro/exercises/ex04_built_in_functions.ipynb
# /home/users/train023/my-ics-work/python-intro/exercises/ex11_conditionals.ipynb
# /home/users/train023/my-ics-work/python-intro/exercises/ex15_programming_style.ipynb
# /home/users/train023/my-ics-work/python-intro/exercises/ex01_running_notebooks.ipynb
# /home/users/train023/my-ics-work/python-intro/exercises/ex14_variable_scope.ipynb
# /home/users/train023/my-ics-work/python-intro/exercises/ex10_for_loops.ipynb
# /home/users/train023/my-ics-work/python-intro/exercises/ex06_dataframes.ipynb
# /home/users/train023/my-ics-work/python-intro/exercises/ex05_libraries.ipynb
# /home/users/train023/my-ics-work/python-intro/exercises/ex07_pandas_dataframes.ipynb
# /home/users/train023/my-ics-work/python-intro/exercises/ex16_wrap_up.ipynb
# /home/users/train023/my-ics-work/python-intro/exercises/ex12_looping_data_sets.ipynb
# /home/users/train023/my-ics-work/python-intro/exercises/ex13_writing_functions.ipynb
# /home/users/train023/my-ics-work/python-intro/exercises/ex08_plotting.ipynb

# %% [markdown]
# How can we return only the files for exercises 1-9?

# %%
for filename in glob.glob('/home/users/train023/my-ics-work/python-intro/exercises/ex0*.ipynb'):
    print(filename)
# Out:
# /home/users/train023/my-ics-work/python-intro/exercises/ex02_variables_assignment.ipynb
# /home/users/train023/my-ics-work/python-intro/exercises/ex03_data_types.ipynb
# /home/users/train023/my-ics-work/python-intro/exercises/ex09_lists.ipynb
# /home/users/train023/my-ics-work/python-intro/exercises/ex04_built_in_functions.ipynb
# /home/users/train023/my-ics-work/python-intro/exercises/ex01_running_notebooks.ipynb
# /home/users/train023/my-ics-work/python-intro/exercises/ex06_dataframes.ipynb
# /home/users/train023/my-ics-work/python-intro/exercises/ex05_libraries.ipynb
# /home/users/train023/my-ics-work/python-intro/exercises/ex07_pandas_dataframes.ipynb
# /home/users/train023/my-ics-work/python-intro/exercises/ex08_plotting.ipynb

# %% [markdown]
# Which exercises have coffee in their title?

# %%
for filename in glob.glob('/home/users/train023/my-ics-work/python-intro/exercises/*pandas*.ipynb'):
    print(filename)
# Out:
# /home/users/train023/my-ics-work/python-intro/exercises/ex07_pandas_dataframes.ipynb

# %% [markdown]
# ## 3. Using `glob` and `for` to process files

# %% [markdown]
# Write a `for` loop which loops through all of the files containing `gdp` in the title, write the data to a dataframe, then print the dataframe minimum for all columns (using `.min()`).

# %%
for filename in glob.glob('/home/users/train023/my-ics-work/python-intro/data/*gdp.csv'):
    df = pd.read_csv(filename)
    print(filename, df.min())
# Out:
# /home/users/train023/my-ics-work/python-intro/data/americas_gdp.csv continent            Americas
# country             Argentina
# gdpPercap_1952    1397.717137
# gdpPercap_1957    1544.402995
# gdpPercap_1962    1662.137359
# gdpPercap_1967    1452.057666
# gdpPercap_1972    1654.456946
# gdpPercap_1977    1874.298931
# gdpPercap_1982    2011.159549
# gdpPercap_1987    1823.015995
# gdpPercap_1992    1456.309517
# gdpPercap_1997    1341.726931
# gdpPercap_2002    1270.364932
# gdpPercap_2007    1201.637154
# dtype: object
# /home/users/train023/my-ics-work/python-intro/data/europe_gdp.csv country               Albania
# gdpPercap_1952     973.533195
# gdpPercap_1957    1353.989176
# gdpPercap_1962    1709.683679
# gdpPercap_1967    2172.352423
# gdpPercap_1972     2860.16975
# gdpPercap_1977    3528.481305
# gdpPercap_1982    3630.880722
# gdpPercap_1987    3738.932735
# gdpPercap_1992    2497.437901
# gdpPercap_1997    3193.054604
# gdpPercap_2002    4604.211737
# gdpPercap_2007    5937.029526
# dtype: object
# /home/users/train023/my-ics-work/python-intro/data/oceania_gdp.csv country             Australia
# gdpPercap_1952    10039.59564
# gdpPercap_1957    10949.64959
# gdpPercap_1962    12217.22686
# gdpPercap_1967    14463.91893
# gdpPercap_1972    16046.03728
# gdpPercap_1977     16233.7177
# gdpPercap_1982     17632.4104
# gdpPercap_1987    19007.19129
# gdpPercap_1992    18363.32494
# gdpPercap_1997    21050.41377
# gdpPercap_2002    23189.80135
# gdpPercap_2007    25185.00911
# dtype: object
